# %%
import torch
import torch.optim as optim
import torch.nn.functional as F
import torchvision
import torchvision.datasets as datasets
import torchvision.models as models
import torchvision.transforms as transforms

from PIL import Image
from IPython.display import display

# %%
test_img = "dataset_v2/full-left/399.jpeg"

# read the input image
img = Image.open(test_img)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x7FADCB7A9E90>

# %%
transform = transforms.Compose([
        transforms.Grayscale(),
        transforms.ColorJitter(0.1, 0.1, 0.1, 0.1),
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.5], [0.5])
    ])

# apply the above tensor on input image
img = transform(img)
transforms.ToPILImage()(img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/ipykernel_30371/1208019157.py in <module>
#       8
#       9 # apply the above tensor on input image
# ---> 10 img = transform(img)
#      11 transforms.ToPILImage()(img)
#
# ~/venvs/mllib2/lib/python3.7/site-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      59     def __call__(self, img):
#      60         for t in self.transforms:
# ---> 61             img = t(img)
#      62         return img
#      63
#
# ~/venvs/mllib2/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/venvs/mllib2/lib/python3.7/site-packages/torchvision/transforms/transforms.py in forward(self, img)
#    1512             PIL Image or Tensor: Grayscaled image.
#    1513         """
# -> 1514         return F.rgb_to_grayscale(img, num_output_channels=self.num_output_channels)
#    1515
#    1516     def __repr__(self):
#
# ~/venvs/mllib2/lib/python3.7/site-packages/torchvision/transforms/functional.py in rgb_to_grayscale(img, num_output_channels)
#    1169         return F_pil.to_grayscale(img, num_output_channels)
#    1170
# -> 1171     return F_t.rgb_to_grayscale(img, num_output_channels)
#    1172
#    1173
#
# ~/venvs/mllib2/lib/python3.7/site-packages/torchvision/transforms/functional_tensor.py in rgb_to_grayscale(img, num_output_channels)
#     136     if img.ndim < 3:
#     137         raise TypeError("Input image tensor should have at least 3 dimensions, but found {}".format(img.ndim))
# --> 138     _assert_channels(img, [3])
#     139
#     140     if num_output_channels not in (1, 3):
#
# ~/venvs/mllib2/lib/python3.7/site-packages/torchvision/transforms/functional_tensor.py in _assert_channels(img, permitted)
#      53     c = get_image_num_channels(img)
#      54     if c not in permitted:
# ---> 55         raise TypeError("Input image tensor permitted channel values are {}, but found {}".format(permitted, c))
#      56
#      57
#
# TypeError: Input image tensor permitted channel values are [3], but found 1
